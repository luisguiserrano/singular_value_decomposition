# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#A = np.array([[2,2],[1,-1]])
A = np.array([[0,1],[2,3]])
#A = np.array([[9,4],[4,3]])

I = np.identity(2)

plt.xlim(-4,4)
plt.ylim(-4,4)

def plot(A, n=100):
    x = np.array([[np.cos(2*np.pi*i/n), np.sin(2*np.pi*i/n)] for i in range(n)])
    y = np.dot(A, x.T).T
    for i in range(n):
        plt.scatter(y[i,0], y[i,1], color=[(n-i)/n, 0, i/n])
plot(I)
plot(A)

X = np.dot(A.T, A)
#plot(X)
#plt.scatter(0.5*(3+np.sqrt(17)), 1, color='black')
#plt.scatter(0.5*(3-np.sqrt(17)), 1, color='black')
plt.scatter(0,0, color='black')

# %%
# SVD
A = A = np.array([[0,1],[-2,-3]])
U = np.array([[-400/1741, 764/785], [764/785, 400/1741]])
sigma = np.array([[1655/447, 0],[0, 894/1655]])
V = np.array([[-521/991, -3725/4379],[-3725/4379, 521/991]])

plt.xlim(-4,4)
plt.ylim(-4,4)
plot(I)
plt.show()
plt.xlim(-4,4)
plt.ylim(-4,4)
plot(V)
plt.show()
plt.xlim(-4,4)
plt.ylim(-4,4)
plot(np.dot(sigma,V))
plt.show()
plt.xlim(-4,4)
plt.ylim(-4,4)
plot(np.dot(np.dot(U,sigma),V))
plt.show()
plt.xlim(-4,4)
plt.ylim(-4,4)
plot(A)
